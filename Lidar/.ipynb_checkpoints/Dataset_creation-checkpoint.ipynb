# %% [markdown]
# # Génération dataset de balises
#
# Ce notebook montre comment le dataset de balises standard est généré : Plusieurs captures de balises ont été effectuées à différentes distances entre 30 cm et 390 cm. chaque mesure a été réalisée 10 fois pour obtenir une meilleure précision sur la forme finale des balises standard. Ici, nous avons extrait chaque balise du nuage de point général obtenu et nous avons calculé une moyenne de chaque mesures.

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# Loading dataset

pd.options.display.max_rows = 100

scan_names = ['data_x=120cm_y=0cm.csv', 'data_x=150cm_y=0cm.csv',
              'data_x=180cm_y=0cm.csv', 'data_x=210cm_y=0cm.csv',
              'data_x=240cm_y=0cm.csv', 'data_x=270cm_y=0cm.csv',
              'data_x=300cm_y=0cm.csv', 'data_x=30cm_y=0cm.csv',
              'data_x=330cm_y=0cm.csv', 'data_x=60cm_y=0cm.csv',
              'data_x=90cm_y=0cm.csv']

dossier = './Train_dataset'

# %%
for file in scan_names :
    df  = pd.read_csv(os.path.join(dossier,file))
    df.plot(x='x', y='y', kind='scatter',marker='.', s=2)
    plt.title(file)
    plt.ylim([-300, 300])
    plt.show()

# %% [markdown]
# ## extraction des balises des scans lidar

# %%
def extraction_balise (dossier : str, fichier_csv : str,
                       zone_balise_gauche : int,
                       zone_balise_droite : int,
                       zone_balise_bas = -300,
                       zone_balise_haut = 300,
                       nb_sample=0) :
    
    # dossier : dossier du fichier csv
    # fichier_csv : Fichier csv de la balise
    # zone_balise_gauche : limite gauche de la zone d'intérêt (axe x)
    # zone_balise_droite : limite droite de la zone d'intérêt (axe x)
    # zone_balise_bas : limite bas de la zone d'intérêt (axe y)
    # zone_balise_haut : limite haut de la zone d'intérêt (axe y)
    
    # Loading data
    df  = pd.read_csv(os.path.join(dossier,fichier_csv))
    
    # Sample number
    if nb_sample == 0 :
        nb_sample = df.iloc[-1,-1] + 1 # last sample number + 1
    
    # Extracting area
    df_extraction = pd.DataFrame(columns=['angle','dist',
                                          'x','y',
                                          'sample'])
    for i in range(df.shape[0]) :
        row = df.iloc[i]
        
        if row['x'] > zone_balise_gauche and row['x'] < zone_balise_droite and row['y'] > zone_balise_bas and row['y'] < zone_balise_haut :
            df_extraction.loc[len(df_extraction)] = row
            #print(row)
            
    return df_extraction

# %% [markdown]
# Extraction sur les mesures de la balise à 120cm

# %%
extract_df = extraction_balise (dossier, scan_names[0], 1100, 1300)
print(extract_df)
# Out:
#          angle    dist            x           y  sample
# 0    -7.569831  1229.0  1218.289317 -161.901641     0.0
# 1    -7.217746  1220.0  1210.332518 -153.281423     0.0
# 2    -6.865661  1200.0  1191.394999 -143.450191     0.0
# 3    -6.513576  1197.0  1189.273372 -135.786036     0.0
# 4    -6.161490  1195.0  1188.096877 -128.260717     0.0
# ...        ...     ...          ...         ...     ...
# 1293 -4.753150  1203.0  1198.862821  -99.684180    99.0
# 1294 -4.401065  1203.0  1199.452746  -92.315278    99.0
# 1295 -4.048979  1204.0  1200.994881  -85.013499    99.0
# 1296 -3.696894  1213.0  1210.475886  -78.212076    99.0
# 1297 -3.344809  1232.0  1229.901279  -71.880768    99.0
#
# [1298 rows x 5 columns]

# %%
# Ploting data x/y
extract_df.plot(x='x', y='y', kind='scatter',marker='.', s=2)
plt.show()

# %% [markdown]
# ## Moyenne des mesures de balises

# %%
def moy_balise(df_balise_extraite : pd.DataFrame) :
    nb_sample = df_balise_extraite.iloc[-1,-1] + 1 # last sample number + 1
    
    #Rounding y values
    df_div = df_balise_extraite.mul({'angle':1,'dist':1, 'x':1, 'y':0.25, 'sample':1})
    df_round = df_balise_extraite.round(0)
    #print(df_round)
    #count = df_round.groupby(by=["y"]).count()
    #print(count)
    
    #Grouping by  y values and removing outliers
    grouped = df_round.groupby(by=["y"])
    df_filter = grouped.filter(lambda x: x["x"].count()>int(nb_sample/2))
    #print(df_filter)
    
    #Calculating mean
    group_sum = df_filter.groupby(by=["y"]).median()
    #print(group_sum)
    return group_sum

# %%
df_balise_standard = moy_balise(extract_df).reset_index()
print(df_balise_standard)

# Ploting data x/y
df_balise_standard.plot(x='x', y='y', kind='scatter',marker='o', s=5)
plt.show()
# Out:
#         y  angle    dist       x  sample
# 0  -162.0   -8.0  1230.0  1219.0    44.5
# 1  -153.0   -7.0  1218.0  1208.0    40.0
# 2  -144.0   -7.0  1206.0  1197.0    42.0
# 3  -136.0   -7.0  1200.0  1192.0    43.0
# 4  -129.0   -6.0  1200.0  1193.0    65.5
# 5  -121.0   -6.0  1196.0  1190.0    47.5
# 6  -114.0   -5.0  1197.0  1192.0    60.5
# 7  -107.0   -5.0  1199.0  1194.0    67.0
# 8   -99.0   -5.0  1197.0  1193.0    40.0
# 9   -92.0   -4.0  1200.0  1196.0    49.0
# 10  -85.0   -4.0  1204.0  1201.0    50.0
# 11  -78.0   -4.0  1211.0  1208.0    47.5
# 12  -72.0   -3.0  1231.0  1229.0    54.5

# %% [markdown]
# ## Creation du dataset de balises

# %%
zone_balise_gauche = [1100,1400,1700,2000,2300,2600,2900,200,3200,500,800]
zone_balise_droite = [1300,1600,1900,2200,2500,2800,3100,400,3400,700,1000]
zone_balise_haut = [300,300,300,300,300,300,300,300,300,300,300]
zone_balise_bas = [-300,-300,-300,-300,-300,-300,-300,-300,-300,-300,-300]

# %%
def extraction_balises_dataset (dossier : str, liste_fichiers,
                                liste_zone_balise_gauche : list,
                                liste_zone_balise_droite : list,
                                liste_zone_balise_bas : list,
                                liste_zone_balise_haut : list) :
    for i in range(len(liste_fichiers)):
        extract_df = extraction_balise (dossier, liste_fichiers[i],
                                        liste_zone_balise_gauche[i],
                                        liste_zone_balise_droite[i],
                                        liste_zone_balise_bas[i],
                                        liste_zone_balise_haut[i])
        #print(extract_df)
        fig, (ax1, ax2) = plt.subplots(1, 2)
        extract_df.plot(ax=ax1, x='x', y='y', kind='scatter',marker='o', s=5)
        
        df_balise_standard = moy_balise(extract_df).reset_index()
        
        # Standardizing format
        df_balise_standard = df_balise_standard.drop('sample', axis=1).copy()
        #print(df_balise_standard)
        
        df_y = df_balise_standard['y'].copy()
        df_balise_standard['y'] = df_balise_standard['angle'].copy()
        df_balise_standard['angle'] = df_balise_standard['dist'].copy()
        df_balise_standard['dist'] = df_balise_standard['x'].copy()
        df_balise_standard['x'] = df_y
        
        col_list = list(df_balise_standard)
        col_list[0], col_list[1], col_list[2], col_list[3] = col_list[1], col_list[2], col_list[3], col_list[0]
        df_balise_standard.columns = col_list
        
        #print(df_balise_standard)
        
        # Ploting data x/y
        df_balise_standard.plot(ax=ax2, x='x', y='y', kind='scatter',marker='o', s=5)
        plt.show()
        
        df_balise_standard.to_csv(index=True)

# %%
extraction_balises_dataset (dossier, scan_names,
                            zone_balise_gauche,
                            zone_balise_droite,
                            zone_balise_bas,
                            zone_balise_haut)
# Out:
#     angle    dist       x      y
# 0    -8.0  1230.0  1219.0 -162.0
# 1    -7.0  1218.0  1208.0 -153.0
# 2    -7.0  1206.0  1197.0 -144.0
# 3    -7.0  1200.0  1192.0 -136.0
# 4    -6.0  1200.0  1193.0 -129.0
# 5    -6.0  1196.0  1190.0 -121.0
# 6    -5.0  1197.0  1192.0 -114.0
# 7    -5.0  1199.0  1194.0 -107.0
# 8    -5.0  1197.0  1193.0  -99.0
# 9    -4.0  1200.0  1196.0  -92.0
# 10   -4.0  1204.0  1201.0  -85.0
# 11   -4.0  1211.0  1208.0  -78.0
# 12   -3.0  1231.0  1229.0  -72.0
#     angle    dist       x      y
# 0    -7.0  1515.5  1505.5 -172.0
# 1    -6.0  1493.0  1485.0 -151.0
# 2    -5.0  1493.0  1486.0 -142.0
# 3    -5.0  1487.0  1481.0 -132.0
# 4    -5.0  1487.0  1482.0 -123.0
# 5    -4.0  1487.0  1483.0 -114.0
# 6    -4.0  1488.0  1484.0 -105.0
# 7    -4.0  1491.0  1488.0  -96.0
# 8    -3.0  1497.0  1494.0  -87.0
# 9    -3.0  1511.0  1509.0  -79.0
# 10   -3.0  1515.0  1513.0  -70.0
#    angle    dist       x      y
# 0   -6.0  1815.0  1806.0 -184.0
# 1   -5.0  1808.0  1800.0 -172.0
# 2   -5.0  1800.0  1793.0 -160.0
# 3   -5.0  1799.0  1793.0 -149.0
# 4   -4.0  1799.0  1794.0 -138.0
# 5   -4.0  1801.0  1797.0 -127.0
# 6   -4.0  1811.0  1807.0 -117.0
# 7   -3.0  1813.0  1810.0 -106.0
#    angle    dist       x      y
# 0   -6.0  2107.0  2095.0 -226.0
# 1   -6.0  2106.0  2095.0 -213.0
# 2   -5.0  2106.0  2096.0 -200.0
# 3   -5.0  2110.0  2102.0 -188.0
# 4   -5.0  2109.0  2102.0 -175.0
# 5   -4.0  2111.0  2105.0 -162.0
# 6   -4.0  2113.0  2108.0 -149.0
#    angle    dist       x      y
# 0   -5.0  2401.0  2393.0 -199.0
# 1   -4.0  2398.0  2391.0 -184.0
# 2   -4.0  2398.0  2392.0 -169.0
# 3   -4.0  2398.0  2393.0 -155.0
# 4   -3.0  2399.0  2395.0 -140.0
# 5   -3.0  2400.0  2397.0 -125.0
#    angle    dist       x      y
# 0   -4.0  2719.0  2712.0 -192.0
# 1   -4.0  2703.0  2697.0 -174.0
# 2   -3.0  2701.0  2696.0 -158.0
# 3   -3.0  2700.0  2696.0 -141.0
# 4   -3.0  2704.0  2701.0 -125.0
# 5   -2.0  2707.0  2705.0 -108.0
# 6   -2.0  2704.0  2702.0  -91.0
#    angle    dist       x      y
# 0   -4.0  3020.0  3012.0 -213.0
# 1   -4.0  2990.0  2984.0 -193.0
# 2   -3.0  2988.0  2983.0 -174.0
# 3   -3.0  2985.0  2981.0 -156.0
# 4   -3.0  2988.0  2985.0 -138.0
# 5   -2.0  2990.0  2988.0 -119.0
# 6   -2.0  2991.0  2989.0 -101.0
#     angle   dist      x     y
# 0   -13.0  293.0  286.0 -65.0
# 1   -12.0  292.0  285.0 -63.0
# 2   -12.0  294.0  287.0 -62.0
# 3   -12.0  291.0  284.0 -61.0
# 4   -12.0  290.5  284.5 -59.0
# 5   -11.0  292.0  286.0 -58.0
# 6   -11.0  289.0  283.0 -57.0
# 7   -11.0  291.0  286.0 -56.0
# 8   -11.0  290.0  285.0 -54.0
# 9   -10.0  289.0  284.0 -52.0
# 10  -10.0  287.0  283.0 -50.0
# 11  -10.0  286.0  282.0 -48.0
# 12   -9.0  288.5  284.5 -47.0
# 13   -9.0  288.0  284.0 -45.0
# 14   -9.0  288.0  285.0 -43.0
# 15   -8.0  290.0  287.0 -42.0
# 16   -8.0  290.0  287.0 -40.0
# 17   -8.0  289.0  286.0 -38.0
# 18   -7.0  292.0  290.0 -37.0
# 19   -7.0  288.0  286.0 -36.0
# 20   -7.0  292.0  290.0 -35.0
# 21   -7.0  292.0  290.0 -33.0
# 22   -6.0  291.0  289.0 -31.0
# 23   -6.0  294.5  292.5 -30.0
# 24   -5.0  294.0  293.0 -28.0
# 25   -5.0  293.5  292.5 -26.0
# 26   -5.0  293.0  292.0 -24.0
# 27   -4.0  291.0  290.0 -22.0
# 28   -4.0  293.0  292.0 -21.0
# 29   -4.0  293.0  292.0 -19.0
# 30   -3.0  293.0  293.0 -17.0
# 31   -3.0  292.0  292.0 -15.0
# 32   -3.0  291.0  291.0 -13.0
# 33   -2.0  292.0  292.0 -12.0
# 34   -2.0  290.0  290.0 -10.0
# 35   -2.0  290.0  290.0  -8.0
# 36   -1.0  290.0  290.0  -6.0
# 37   -1.0  289.0  289.0  -4.0
# 38   -1.0  289.0  289.0  -3.0
# 39   -0.0  289.0  289.0  -1.0
# 40    0.0  290.0  290.0   1.0
# 41    1.0  290.0  290.0   3.0
# 42    1.0  290.0  290.0   4.0
# 43    1.0  292.0  292.0   6.0
# 44    2.0  293.0  293.0   8.0
# 45    2.0  294.0  294.0  10.0
# 46    2.0  294.0  294.0  12.0
# 47    3.0  297.0  297.0  14.0
# 48    3.0  300.0  300.0  16.0
# 49    3.0  309.0  308.0  18.0
